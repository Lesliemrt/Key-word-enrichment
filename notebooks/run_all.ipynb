# %%
from pygbif import species

import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.pipeline.gbif_check import result_csv
from src.pipeline.evaluator import Evaluator
# Out:
# {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}
# {'precision': 1.0, 'recall': 0.9473684210526315, 'f1-score': 0.972972972972973}
# {'precision': 1.0, 'recall': 0.8947368421052632, 'f1-score': 0.9444444444444444}
