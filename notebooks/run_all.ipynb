# %%
from pygbif import species

import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.pipeline.gbif_check import result_csv
from src.pipeline.evaluator import Evaluator

# %%
evaluator = Evaluator()
result = pd.read_csv("result.csv", sep=",")

# %%
targets_species = result['Species'].str.replace(r"[\[\]']", "", regex=True)
predictions_species  = result['Taxon'].str.replace(r"[\[\]']", "", regex=True)
print(targets_species)
# Out:
# 0                                       Ostrea edulis\n
# 1     Epinephelus marginatus, Sciaena umbra, Diplodu...
# 2                                  Lyallia kerguelensis
# 3                                 Trisopterus minutus\n
# 4                Ophiocomina nigra, Ophiothrix fragilis
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                   Chlamys varia, Mimachlamys varia\n
# 12    Capreolus capreolus, Cervus elaphus, Ovis gmel...
# 13                   Chlamys varia, Mimachlamys varia\n
# 14                                                  NaN
# 15                    Puffinus gravis, Puffinus griseus
# 16                                                  NaN
# ...

# %%
print(predictions_species[0])
# Out:
# ['Ostrea edulis', 'Ostrea edulis']

# %%
print(type(targets_species[1]))
print(type(predictions_species[1]))
# Out:
# <class 'list'>
# <class 'str'>
